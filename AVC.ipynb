# %%
var('x y')
p = (-1,1)
raizp = (2^(1/4)*sin(3*pi/8).n(),2^(1/4)*cos(3*pi/8).n())
implicit_plot(x^2+y^2==3,(x,-2,2),(y,-2,2),color='green') + implicit_plot(x^2+y^2==0.2,(x,-2,2),(y,-2,2),color='green') +\
line([(0,-2),(0,2)]) + line([(-2,0),(2,0)]) + point((-1,1),color = 'red',legend_label='P')+ point((raizp),legend_label='Raíz de P')
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
var('x y')
p = (-1,1)
implicit_plot(x^2+y^2==3,(x,-2,2),(y,-2,2),color='green') + implicit_plot(x^2+y^2==0.2,(x,-2,2),(y,-2,2),color='green') +\
implicit_plot(x^2+y^2==0.3,(x,-2,2),(y,0,2),color='blue') + implicit_plot(x^2+y^2==0.3,(x,-2,2),(y,-2,0),color='red') +\
implicit_plot(x^2+y^2==2,(x,-2,2),(y,0,2),color='blue')   +  implicit_plot(x^2+y^2==2,(x,-2,2),(y,-2,0),color='red') +\
line([(0,-2),(0,2)],color = 'pink') + line([(-2,0),(2,0)],color = 'pink') + point((0.7,0.9),color = 'orange',legend_label='z') +\
line([(-1,-1),(0,0)],color = 'red',legend_label='R') + line([(0,0),(0.38,0.38)],color='blue',legend_label='r')
# Out:
# Graphics object consisting of 11 graphics primitives
